# %%
import tabula
import os
import matplotlib.pyplot as plt
from ipywidgets import interact
import warnings
from tabula.io import read_pdf
warnings.simplefilter(action='ignore')
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15316/3967719162.py in <module>
#      10 import numpy as np
#      11 import matplotlib.pyplot as plt
# ---> 12 from wordcloud import WordCloud
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
import pandas as pd
# create an empty dataframe that will collect all the data
df  = pd.DataFrame()
for i in os.listdir("Transactions"):
    
    if ".pdf" in i:
        try:
            print(i)
            #create yet another dataframe that will collect all data from each page
            temp = pd.DataFrame()
            data = read_pdf("2020_statements/" +i, pages='all',password = "27349952",multiple_tables=True)
            print("read...")
            for i in range(1,len(data)):
                temp = pd.concat((data[i],temp),0)
                #print(temp.shape)
            dt = pd.DataFrame(temp)
            df = pd.concat((df,dt),0)
            
            #print(data.head(2))
        except:
            print("cant")
            pass
# Out:
# MPESA_Statement_20201108_to_20211108_254710972786.pdf
# Got stderr: Mar 17, 2022 10:19:22 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Mar 17, 2022 10:19:22 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Mar 17, 2022 10:19:23 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 386 fonts
# read...

# %%
# clean the df

df["Completion Time"] = pd.DatetimeIndex(df["Completion Time"])
df["Month"]= [i.month_name() for i in df["Completion Time"]]

# %%
import sqlite3
conn = sqlite3.connect("Mpesa1.db")
# send the data to the database so I wont have to keep on reading the pdfs
df.to_sql("Mpesa",conn,if_exists='replace')
df.head()
# Out:
#   Receipt No.     Completion Time  \
# 0  OK85AXLN1H 2020-11-08 14:23:34
# 1  OK87AXKOZF 2020-11-08 14:22:56
# 2  OK82AXBTJU 2020-11-08 14:17:24
# 3  OK80AOYENA 2020-11-08 10:46:57
# 0  OKG1KBI62T 2020-11-16 15:53:00
#
#                                              Details Transaction\rStatus  \
# 0  Customer Withdrawal At Agent Till 292054 - Gen...           Completed
# 1                                KCB M-PESA Withdraw           Completed
# 2                                   Airtime Purchase           Completed
# 3                                   Airtime Purchase           Completed
# 0  Customer Withdrawal At Agent Till 594601 - Azi...           Completed
#
#     Paid In   Withdrawn   Balance  Unnamed: 0 Transaction     Month
# 0       NaN   -6,000.00    422.13         NaN         NaN  November
# 1  6,000.00         NaN  6,422.13         NaN         NaN  November
# 2       NaN      -50.00    422.13         NaN         NaN  November
# 3       NaN      -50.00    472.13         NaN         NaN  November
# 0       NaN  -34,000.00    519.62         NaN         NaN  November

# %% [markdown]
# # Airtime analysis

# %%
def cleaner(lis):
    clean = []
    for i in lis:
        try:
            x = i.replace("-","").replace(",","")
            clean.append(float(x))
        except:
            clean.append(np.nan)
    return clean

class MpesaAnalyzer:
    def __init__(self,conn,data =None):
        self.conn = conn
        self.data = data
    
    def Airtime(self):
        data = pd.read_sql("""select Month,-1*SUM(Withdrawn)
        from Mpesa 
        where Details like '%airtime%' 
        group by month 
        order by Month""",self.conn)
        data.columns = ["x","y"]
        self.data = data
        data['x'] = pd.Categorical(data['x'],categories =['January',  'February','March',  'April','May','June', 'July',  'August', 'September','October', 'November','December'] ,ordered =True)
        
        plt.figure(figsize = (15,7))
        graph = sns.barplot(data = data,x = "x",y = "y")
        for p in graph.patches:
            graph.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()),
                        ha='center', va='bottom',
                        color= 'black')
        plt.title("Mpesa Airtime plot")
        return plt.show()
    
    def Charges(self):
        data = pd.read_sql("""select Month,-1*sum(Withdrawn) from Mpesa where Details like '%charge%' group by month order by Month """,self.conn)
        data.columns = ["x","y"]
        self.data = data
        data['x'] = pd.Categorical(data['x'],categories =['January',  'February','March',  'April','May','June', 'July',  'August', 'September','October', 'November','December'] ,ordered =True)
        plt.figure(figsize = (15,7))
        graph = sns.barplot(data = data,x = "x",y = "y")
        for p in graph.patches:
            graph.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()),
                        ha='center', va='bottom',
                        color= 'black')
        plt.title("Mpesa Charges plot")
        return plt.show()
    
    def Number_analysis(self,name,title = ""):
        name = "254" + name[len(name)-9:len(name)]
        data = pd.read_sql("""select  * from Mpesa where Details like '%{}%'  """.format(name),conn)
        data = data[["Month","Withdrawn","Paid In"]]
        data['Withdrawn'] = cleaner(data['Withdrawn'])
        data['Paid In'] = cleaner(data['Paid In'])
        data = data.groupby("Month").agg(["sum"]).reset_index()
        data.columns = ["Month","Withdrawn","Paid In"]
        self.data = data
        data["Month"] = pd.Categorical(data["Month"],categories =['January',  'February','March',  'April','May','June', 'July',  'August', 'September','October', 'November','December'] ,ordered =True)
        data1 = data.pivot_table(index='Month',
               margins=True,
               margins_name='total',  # defaults to 'All'
               aggfunc=sum)
        data_melt = data.melt(id_vars = "Month")
        plt.figure(figsize = (15,7))
        graph = sns.barplot(data = data_melt,x = "Month",y = "value",hue = "variable")
        plt.title(title)
        for p in graph.patches:
            graph.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()),
                        ha='center', va='bottom',
                        color= 'black')
        
        return plt.show(),print(data1)
    def general_analyzer(self,keyword):
        name = keyword
        data = pd.read_sql("""select  * from Mpesa where Details like '%{}%'  """.format(name),conn)
        data = data[["Month","Withdrawn","Paid In"]]
        data['Withdrawn'] = cleaner(data['Withdrawn'])
        data['Paid In'] = cleaner(data['Paid In'])
        data = data.groupby("Month").agg(["sum"]).reset_index()
        data.columns = ["Month","Withdrawn","Paid In"]
        self.data = data
        data["Month"] = pd.Categorical(data["Month"],categories =['January',  'February','March',  'April','May','June', 'July',  'August', 'September','October', 'November','December'] ,ordered =True)
        
        data_melt = data.melt(id_vars = "Month")
        plt.figure(figsize = (15,7))
        graph = sns.barplot(data = data_melt,x = "Month",y = "value",hue = "variable")
        for p in graph.patches:
            graph.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()),
                        ha='center', va='bottom',
                        color= 'black')

        return plt.show()
    def Frequent(self,number = 10):
        data = pd.read_sql("""select  * from Mpesa """,conn)
        names = []
        for i in data['Details']:
            try:
                x = i.split("-")[1].replace("\r"," ")\
                .replace("  ","")
                names.append("_".join(x.split()[:3]))
            except:
                names.append("") 
        data['people'] = names
        test1 = data.people.value_counts()
        dt = pd.DataFrame(test1)
        dt = dt[dt['people']!=" "]
        dt.columns = ["Accounts_frequently_transacted_with"]
        plt.figure(figsize = (10,10))
        word_cloud = WordCloud(collocations = False, background_color = 'white').generate(" ".join(names))
        plt.imshow(word_cloud, interpolation='bilinear')
        plt.axis("off")
        
        
        return (plt.show(),dt.head(number).iloc[1:number,:])

# %%
analysis = MpesaAnalyzer(conn)
#analysis.Airtime()
#analysis.Charges()
analysis.Number_analysis("0723251279",title= "Newton transaction")
#analysis.general_analyzer("selfridges")
#analysis.Frequent()
#analysis.data
# Out:
#            Paid In  Withdrawn
# Month
# January        0.0     1500.0
# February       0.0      500.0
# March          0.0     8422.0
# April          0.0     2000.0
# May            0.0    10612.0
# June        9000.0     2760.0
# July        9560.0    17117.0
# August         0.0     2782.0
# September      0.0    11500.0
# October        0.0    10850.0
# November       0.0    15057.0
# December       0.0     1500.0
# total      18560.0    84600.0
# (None, None)

# %%
analysis.general_analyzer("internet")

# %%
analysis.Airtime()

# %%
analysis.data
# Out:
#         Month  Withdrawn   Paid In
# 0       April    67770.0   12000.0
# 1      August    38100.0   22000.0
# 2    December   144750.0       0.0
# 3    February    91890.0   12100.0
# 4     January    36300.0   85000.0
# 5        July    41650.0   78720.0
# 6        June    64800.0  126000.0
# 7       March    10850.0  148000.0
# 8         May    52760.0  196000.0
# 9    November   140230.0   23000.0
# 10    October    16400.0  117000.0
# 11  September    49950.0  304000.0

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from string import punctuation
x = []
for i in data.Details:
    for j in nltk.word_tokenize(str(i)):
        x.append(j)
from nltk.corpus import stopwords
stoplist = stopwords.words('english') + ['though']+list(punctuation)
x = [i.lower() for i in x if not i in stoplist ]
# Out:
# [nltk_data] Downloading package punkt to C:\Users\John Kamau
# [nltk_data]     K\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\John Kamau
# [nltk_data]     K\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
freq = nltk.FreqDist(x)
import matplotlib.pyplot as plt

plt.figure(figsize = (20,7))
freq.plot(40)
plt.show()

# %%
names
# Out:
# ['Generations Insight Ndumberi',
#  'PESA Withdraw',
#  '',
#  '',
#  'Azimio Ents Ltd',
#  'B2C LOOP VIA',
#  '',
#  'Spiders Mobile Moi',
#  'PHELICAN AKINYI OGUTU',
#  '',
#  'Willing Agencies Ltd',
#  '',
#  '',
#  'Alex Peter Gatangi',
#  '',
#  '',
#  'Nakels Co. Ltd',
#  'B2C LOOP VIA',
#  '',
#  'SUSAN KAMAU',
#  '',
#  '',
#  '',
#  'EDWARD KAMAU NYOORI',
#  '',
#  'B2C LOOP VIA',
#  '',
#  '',
#  '',
#  'Kablingi Ltd Diana',
#  'B2C LOOP VIA',
#  '',
#  'Webhost Kenya Ltd.',
#  'B2C LOOP VIA',
#  '',
#  '',
#  '',
#  'MARY MUIGAI',
#  'CLEAN SHELF SUPERMARKETS',
#  'IMMENSITY HOLDINGS LTD',
#  '',
#  '',
#  '',
#  'KENNEDY NJAU NGANGA',
#  'GIDEON GITAU THAGICHU',
#  'B2C LOOP VIA',
#  'M',
#  '',
#  '',
#  'Pesa to 254757160314',
#  'PESA Withdraw',
#  'STEPHEN WANYOIKE',
#  'PESA Withdraw',
#  '',
#  'M',
#  'CHIME INC',
#  '',
#  '',
#  'Pesa to 254724361219',
#  '',
#  'STEPHEN MUTURI NGANGA',
#  'Newton Mbugua',
#  '',
#  'B2C LOOP VIA',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  'Wimtech comm city',
#  '',
#  'ERICK MUSEVE',
#  'TBC THIKA RD',
#  '',
#  'JOHN KAMAU WAMBUI',
#  'Shwari Withdraw',
#  '',
#  'ELIUD KINUTHIA',
#  '',
#  'DOUGLAS KANYIRI',
#  'RAHAB WANJIKU NGUGI',
#  'DAVID KINYANJUI',
#  'PETER GAITHO WAINAINA',
#  '',
#  '',
#  '',
#  'KENNEDY NJAU NGANGA',
#  'Family Bank Ltd',
#  'TOTAL WANGIGE',
#  '',
#  'ARIDLANDS COMMUNICATION LIMITED',
#  'B2C LOOP VIA',
#  '',
#  '',
#  'FRANCIS WAWERU MUMBI',
#  'B2C LOOP VIA',
#  '',
#  '',
#  'Shwari Withdraw',
#  'Shwari Deposit',
#  'ERICK MUSEVE',
#  'Equity Paybill Account',
#  'B2C LOOP VIA',
#  'BENSON MUSYOKI MUTINDA',
#  '',
#  'PESA Deposit',
#  'Shwari Deposit',
#  'PESA Deposit',
#  'ERICK MUSEVE',
#  '',
#  '',
#  '',
#  '',
#  'Casha Marketeers LTD',
#  'PI CONSULTING SERVICES',
#  'Shwari Deposit',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'BASIL Comm ROSETTI',
#  '',
#  'Generations Insight Ndumberi',
#  'MICHAEL MBUGUA MUCHABA',
#  'NAOMI THUMBI KIMANI',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'JOHN KAMAU WAMBUI',
#  'SMARTEYE LTD Acc.',
#  'JOHN KAMAU WAMBUI',
#  'M',
#  '',
#  '',
#  'Pesa to 254726027725',
#  'M',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'Pesa to 254717825148',
#  '',
#  'Pesa to 254718079089',
#  '',
#  'SEVEN STAR WINNIES',
#  '',
#  'M',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'Pesa to 254757160314',
#  '',
#  '',
#  '',
#  'Gemini konnexionShop Kikuyu',
#  '',
#  'M',
#  'Family Bank Ltd',
#  '',
#  'Pesa to 247247',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'Silkmac Comm Wangige',
#  '',
#  '',
#  '',
#  'ERICK MUSEVE',
#  '',
#  'Silkmac Comm Wangige',
#  'ALICE KAMAU',
#  'GRACE WANJA MUGO',
#  '',
#  'RACHEL NDATHE',
#  'PESA Withdraw',
#  'DAMARIS NDUTA GITHUA',
#  '',
#  'Linkup Connections 3',
#  '',
#  'Linkup Connections 3',
#  '',
#  'DAMARIS NDUTA GITHUA',
#  'Shwari Deposit',
#  'JOHN KAMAU WAMBUI',
#  'PESA Deposit',
#  'EUNICE KAMAU',
#  '',
#  'Stephen Gichuki Karathe',
#  '',
#  'Carolma Comm unitec',
#  'Shwari Deposit',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  'KEVIN MWANGI WANJIKU',
#  '',
#  'Alex Peter Gatangi',
#  '',
#  'RUI RURAL URBAN',
#  '',
#  'Leah Wangui Kamau',
#  'PESA Deposit',
#  '',
#  '',
#  'LINET WANJA NGUGI',
#  'ERICK MUSEVE',
#  '',
#  'SIMON KURIA MWAURA',
#  'GITHUNGURI SELFRIDGES SUPERMARKET',
#  '',
#  '',
#  'Bluebell Modece Enterprises',
#  'GERALD KINUTHIA',
#  'EUNICE NJERI KAMAU',
#  '',
#  '',
#  '',
#  'Carolma Comm unitec',
#  'RAHAB WANJIKU NGUGI',
#  'CHIME INC',
#  'GEORGE NJUGUNA NGURU',
#  'GEORGE NJUGUNA NGURU',
#  'KEVIN MWANGI WANJIKU',
#  'LUCY MUTUA',
#  'RAHAB WANJIKU NGUGI',
#  'SAFARICOM POSTPAID BUNDLES',
#  '',
#  '',
#  'NOEL AWINJA ABUKUSE',
#  '',
#  '',
#  'NCBA LOOP Acc.',
#  '',
#  'NCBA LOOP Acc.',
#  'PESA Withdraw',
#  'AMAYA TECHNOLOGY COMPANY',
#  'PESA Withdraw',
#  'SIA QSR KENYA',
#  '',
#  '',
#  'Kabonet Communication Limited',
#  'AGNES WANJIKU WAWERU',
#  '',
#  'Symmetrics Consulting Mololine',
#  'PESA Withdraw',
#  'walter karanja',
#  '',
#  'Mary Njeri Githiga',
#  'JOHN KAMAU WAMBUI',
#  'DEEDS PRODUCTION LIMITED',
#  'FACESHOP COMPANY LIMITED',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  'Alex Peter Gatangi',
#  'PESA Withdraw',
#  'EUNICE MWAURA',
#  'GEORGE NJUGUNA NGURU',
#  'KEVIN MWANGI WANJIKU',
#  '',
#  '',
#  '',
#  'SARAH NDEGWA',
#  'Biashara Holdings Kago',
#  '',
#  'B2C LOOP VIA',
#  '',
#  'Ever comm ltd',
#  'GITHUNGURI SELFRIDGES SUPERMARKET',
#  '',
#  'SEVEN STAR WINNIES',
#  '',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  'KENNEDY NJAU NGANGA',
#  '',
#  'SUSAN KAMAU',
#  'JOHN KAMAU WAMBUI',
#  'RAHAB WANJIKU NGUGI',
#  'SAFARICOM POSTPAID BUNDLES',
#  'CHIME INC',
#  '',
#  '',
#  'Slopeline Comms Hairport',
#  'B2C LOOP VIA',
#  '',
#  '',
#  'Biashara Holdings Kago',
#  '',
#  'Skyline Walokana society',
#  '',
#  'FRACTIONAL MOBILE cannon',
#  'Shwari Withdraw',
#  'CHIME INC',
#  'JOHN KAMAU WAMBUI',
#  '',
#  "FRANCIS WAKABA NG'ANG'A",
#  '',
#  '',
#  'SIMON KURIA MWAURA',
#  '',
#  'ALICE KAMAU',
#  'B2C LOOP VIA',
#  'GEORGE NJUGUNA NGURU',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  'Carolma Comm unitec',
#  'TOTAL RUAKA',
#  '',
#  '',
#  'NCBA LOOP Acc.',
#  'PETER GAITHO WAINAINA',
#  'ALICE KAMAU',
#  'Shwari Withdraw',
#  '',
#  'Shwari Withdraw',
#  '',
#  '',
#  'Linkup Connections 3',
#  'Shwari Withdraw',
#  '',
#  '',
#  'M',
#  'Newton Mbugua',
#  '',
#  'Pesa to 254703223621',
#  '',
#  '',
#  'Carolma Comm unitec',
#  'MARY KALEKYE',
#  '',
#  'SAFARICOM POSTPAID BUNDLES',
#  '',
#  'Biashara Holdings Kago',
#  'ALICE KAMAU',
#  '',
#  'Carolma Comm unitec',
#  'JOHN KAMAU KARIUKI',
#  '',
#  '',
#  'JOHN KAMAU WAMBUI',
#  'JOHN WHITE',
#  '',
#  'Nakels Co. Ltd',
#  'EDWARD KAMAU NYOORI',
#  '',
#  '',
#  '',
#  'Biashara Holdings Kago',
#  'esther ngugi',
#  'MICHAEL NJENGA 1',
#  '',
#  'ALICE KAMAU',
#  'PESA Withdraw',
#  'ST. ANGELA MERICIS',
#  'Shwari Deposit',
#  'ST. ANGELA MERICIS',
#  'Nelson Macharia Mwangi',
#  'JOHN KAMAU KARIUKI',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  '',
#  'TITUS WAWERU KAMAU',
#  '',
#  'Jank Telecom Inv',
#  '',
#  'RAHAB WANJIKU NGUGI',
#  '',
#  '',
#  'Basil Comms smiles',
#  "Tai's Chicken Grill",
#  '',
#  '',
#  'RUI RURAL URBAN',
#  '',
#  'Alex Peter Gatangi',
#  '',
#  'JOHN KAMAU KARIUKI',
#  '',
#  'Leah Wangui Kamau',
#  '',
#  'STEPHEN KARATHE',
#  '',
#  'LINET WANJA NGUGI',
#  '',
#  'FARMERS BUTCHERY VIA',
#  '',
#  'Biashara Holdings Kago',
#  '',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'brian gathara wainaina',
#  '',
#  'NCBA LOOP Acc.',
#  '',
#  'Willy Waweru Kiarie',
#  'PI CONSULTING SERVICES',
#  'PI CONSULTING SERVICES',
#  'james mambo',
#  'M',
#  'CHIME INC',
#  '',
#  'Pesa to 254726237795',
#  '',
#  'Pesa Online to',
#  '',
#  'LUCY MURUGI WANJIKU',
#  'B2C LOOP VIA',
#  'PI CONSULTING SERVICES',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'SAMUEL WANGARI',
#  '',
#  'Biashara Holdings Kago',
#  'EDWARD KAMAU NYOORI',
#  '',
#  '',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'EUNICE KAMAU',
#  'Skyline Walokana society',
#  '',
#  'MT KENYA GENERAL',
#  '',
#  '',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'EUNICE NJOKI WAINAINA',
#  '',
#  'Mwokom Invest Wangige',
#  '',
#  '',
#  'EUNICE KAMAU',
#  '',
#  'LinkUp Conns QubaTech',
#  'M',
#  'B2C LOOP VIA',
#  '',
#  'Pesa to 244441',
#  '',
#  '',
#  'MARGARET WAIRIMU WANJIKU',
#  "Tai's Chicken Grill",
#  'MINIME BASICS',
#  'B2C LOOP VIA',
#  'City Star Restaurant',
#  '',
#  'SCIENCESCOPE LIMITED Acc.',
#  'B2C LOOP VIA',
#  '',
#  'PAUL K MWANGI',
#  '',
#  'ACE LOCKS AND',
#  '',
#  'ACE LOCKS AND',
#  'B2C LOOP VIA',
#  '',
#  '',
#  '',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'SOFT MOBILES TELCOMUNICATIONS',
#  '',
#  'CHARITY KAMAU',
#  '',
#  'DANIEL WAWERU KAMAU',
#  '',
#  'DANIEL WAWERU KAMAU',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'Tsavocom Investment Company',
#  '',
#  'DANIEL WAWERU KAMAU',
#  '',
#  'Gintech Solnsunication Sabby',
#  'ERICK MUSEVE',
#  '',
#  'KENYA CHARITY SWEEPSTAKE',
#  '',
#  'Stephen muturi githinji',
#  '',
#  'FRACTIONAL MOBILE cannon',
#  '',
#  '',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'DANIEL WAWERU KAMAU',
#  '',
#  '',
#  'Skyline Ltd K',
#  'GEORGE NJUGUNA NGURU',
#  '',
#  '',
#  'DANIEL WAWERU KAMAU',
#  'B2C LOOP VIA',
#  '',
#  '',
#  'Lurai Ents Ltdvanga',
#  'GEORGE NJUGUNA NGURU',
#  '',
#  'JOHN KAMAU KARIUKI',
#  '',
#  'Karori General Merchants',
#  '',
#  'KENNEDY NJAU NGANGA',
#  '',
#  '',
#  'jonh kamotho kuria',
#  'Pesa to 254757160314',
#  '',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'Brothermini Comm markel',
#  'GEORGE NJUGUNA NGURU',
#  '',
#  '',
#  '',
#  'SIMON KURIA MWAURA',
#  'Mwokom Invest Wangige',
#  'M',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  'Pesa to 254723245622',
#  'FRACTIONAL MOBILE cannon',
#  '',
#  '',
#  '',
#  'BREAKTHROUGH COMPANY LIMITED',
#  '',
#  '',
#  'JAMES WANJIRU',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'ALICE KAMAU',
#  '',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  '',
#  '',
#  'PETER KIBUTHA MACHARIA',
#  'PETER KIBUTHA MACHARIA',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'Gintech Solnsunication Sabby',
#  '',
#  'ALICE KAMAU',
#  '',
#  'INTERGLOBAL Invest Co',
#  '',
#  'Biashara Holdings Kago',
#  'EDWARD KAMAU NYOORI',
#  '',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  'DANIEL WAWERU KAMAU',
#  '',
#  'NOEL AWINJA ABUKUSE',
#  '',
#  'Lurai Ents Ltdvanga',
#  'B2C LOOP VIA',
#  '',
#  'Alex Peter Gatangi',
#  '',
#  '',
#  'NELLEY MAINA',
#  '',
#  'KENNEDY NJAU NGANGA',
#  'M',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  'Pesa to 254757160314',
#  '',
#  '',
#  'Pesa to 254713714971',
#  '',
#  'Carolma Comm unitec',
#  '',
#  'JAMES WANJIRU',
#  '',
#  'William Kinyanjui Mbote',
#  'ST. ANGELA MERICIS',
#  '',
#  'William Kinyanjui Mbote',
#  '',
#  '',
#  'EASTLEIGH MATTRESSES LIMITED',
#  '',
#  '',
#  'Express Arts Peters',
#  'ERICK MUSEVE',
#  'JENGA MAISHA LIMITED',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  'Trio Star invests',
#  'EDWARD KAMAU NYOORI',
#  'M',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  'Pesa to 254723390702',
#  '',
#  'Karuma Supermarket Wangige',
#  'klub queens 3',
#  'M',
#  'B2C LOOP VIA',
#  '',
#  '',
#  'ALICE KAMAU',
#  'B2C LOOP VIA',
#  'JOHN KAMAU WAMBUI',
#  'PESA Withdraw',
#  '',
#  'Mwokom Invest Wangige',
#  'PESA Withdraw',
#  '',
#  'PESA Deposit',
#  '',
#  'SUSAN KAMAU',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'New Exchange Wholesalers',
#  '',
#  'Atlantiscom Telecomm Ltdshoppers',
#  '',
#  'Riyadh Comms Ltd',
#  'B2C LOOP VIA',
#  '',
#  'KILIMANJARO JAMIAT S',
#  '',
#  'JOHN KAMAU KARIUKI',
#  '',
#  '',
#  'NEWA PROPERTIES LIMITED',
#  'PESA Deposit',
#  'JOHN KAMAU WAMBUI',
#  'DOUGLAS NJOROGE 1',
#  'GEORGE NJUGUNA NGURU',
#  '',
#  '',
#  'NCBA LOOP Acc.',
#  '',
#  'RUI RURAL URBAN',
#  'Kingdom Bank Limited',
#  '',
#  'EUNICE KAMAU',
#  '',
#  'AGNES KARITA',
#  'PESA Deposit',
#  '',
#  '',
#  'MARGARET WAIRIMU WANJIKU',
#  '',
#  'SUSAN KAMAU',
#  '',
#  'Alex Peter Gatangi',
#  '',
#  'NOEL AWINJA ABUKUSE',
#  'PI CONSULTING SERVICES',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'LinkUp Conns QubaTech',
#  '',
#  '',
#  'City Star Restaurant',
#  '',
#  'LIFE',
#  '',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'Alex Peter Gatangi',
#  '',
#  '',
#  'Alex Peter Gatangi',
#  '',
#  'JOHN KAMAU KARIUKI',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'Gee Logistics ltdKen',
#  '',
#  'SUSAN KAMAU',
#  '',
#  '',
#  '',
#  'TWEIN ENGINEERING LIMITEDpeterze',
#  '',
#  '',
#  'Paradise lost',
#  '',
#  '',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  'Lurai Ents Ltdvanga',
#  '',
#  'PETER NYANJUI WAMWATI',
#  'M',
#  'B2C LOOP VIA',
#  '',
#  '',
#  'Pesa to 254729250334',
#  '',
#  '',
#  'Alex Peter Gatangi',
#  '',
#  'LinkUp Conns QubaTech',
#  'KEVIN MWANGI WANJIKU',
#  'GEORGE NJUGUNA NGURU',
#  'Masters Manufacteres Gikuni',
#  '',
#  '',
#  'GEORGE NJUGUNA NGURU',
#  '',
#  'JOSHUA NDIRANGU MACHARIA',
#  '',
#  'Danshe TelecomsKIRAMIDI SHOPGIKUNI',
#  'JOHN KAMAU WAMBUI',
#  'M',
#  'Alex Peter Gatangi',
#  'M',
#  'Skyline Walokana society',
#  '',
#  '',
#  'Pesa to 254719679231',
#  '',
#  '',
#  'Pesa to 254723245622',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'LinkUp Conns QubaTech',
#  'KEVIN MWANGI WANJIKU',
#  'B2C LOOP VIA',
#  'EDWARD KAMAU NYOORI',
#  'PETER GITHIRI MACHARIA',
#  '',
#  '',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  'Jank Telecom Inv',
#  '',
#  '',
#  'JEREA VENTURES COMPANY',
#  '',
#  'Skyline Ltd K',
#  'M',
#  'B2C LOOP VIA',
#  '',
#  '',
#  'Pesa to 254726237795',
#  '',
#  'Pesa Online to',
#  '',
#  '',
#  'Biashara Holdings Kago',
#  '',
#  "FRANCIS WAKABA NG'ANG'A",
#  'RUI RURAL URBAN',
#  '',
#  'NOEL AWINJA ABUKUSE',
#  'ERICK MUSEVE',
#  'M',
#  '',
#  '',
#  'Pesa to 254757160314',
#  'M',
#  'Guaranty Trust Bank',
#  'M',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  'Pesa to 254723251279',
#  '',
#  '',
#  'Pesa to 254757160314',
#  '',
#  'Danshe TelecomsKIRAMIDI SHOPGIKUNI',
#  '',
#  'ARIDLANDS COMMUNICATION LIMITED',
#  '',
#  'ZUKHRUF JAKAS SALOON',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'Carolma Comm unitec',
#  'GEORGE NJUGUNA NGURU',
#  '',
#  'Lurai Ents Ltdvanga',
#  'MICHAEL NJENGA 1',
#  'KEVIN MWANGI WANJIKU',
#  'M',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  'Pesa to 254757160314',
#  '',
#  'ALICE KAMAU',
#  'Mwokom Invest Wangige',
#  '',
#  '',
#  'LINET WANJA NGUGI',
#  '',
#  'Lurai Ents Ltdvanga',
#  'GEORGE NJUGUNA NGURU',
#  '',
#  '',
#  '',
#  'Alex Peter Gatangi',
#  '',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  'Mwokom Invest Wangige',
#  '',
#  '',
#  'Alex Peter Gatangi',
#  '',
#  '',
#  'Lurai Ents Ltdvanga',
#  'Shwari Withdraw',
#  'B2C LOOP VIA',
#  '',
#  'Null Equal Ltdvarun',
#  'LUCY NJERI MUMBI',
#  '',
#  'PETER GAITHO WAINAINA',
#  '',
#  '',
#  'LINET WANJA NGUGI',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'Alex Zacharia Boro',
#  '',
#  'KEVIN MWANGI WANJIKU',
#  '',
#  'NCBA LOOP Acc.',
#  '',
#  'PETER GITHIRI MACHARIA',
#  'Kingdom Bank Limited',
#  'PESA Withdraw',
#  'PESA Deposit',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'SUSAN KAMAU',
#  '',
#  'JOHN KAMAU KARIUKI',
#  '',
#  'Ever comm next',
#  'GITHUNGURI SELFRIDGES SUPERMARKET',
#  'Shwari Deposit',
#  'PESA Deposit',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'LINET WANJA NGUGI',
#  '',
#  'muigai kamau',
#  '',
#  'Mwokom Invest Wangige',
#  '',
#  '',
#  '',
#  'CHARLES KINUTHIA KAMAU',
#  '',
#  '',
#  'LinkUp Conns QubaTech',
#  'KEVIN MWANGI WANJIKU',
#  '',
#  'NCBA LOOP Acc.',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'Jamleck Thuo Mwangi',
#  'Interworld Wine Agency',
#  '',
#  'EUNICE NJERI KAMAU',
#  '',
#  '',
#  'Peter Githua Igogo',
#  '',
#  'MARY GATHONI MUNGAI',
#  '',
#  'JOHN KAMAU KARIUKI',
#  '',
#  'SUSAN KAMAU',
#  '',
#  'NCBA LOOP Acc.',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'LURAI ent Kingoro',
#  'QUEENS CLASSY COLLECTIONS',
#  '',
#  'CECILIA GATHONI NJENGA',
#  'Family Bank Fourways',
#  '',
#  'NICKO GYM AND',
#  'NICKO GYM AND',
#  '',
#  'Mwokom Invest Wangige',
#  '',
#  'EDWARD KAMAU NYOORI',
#  '',
#  'NCBA LOOP Acc.',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'ALICE KAMAU',
#  '',
#  'SUSAN KAMAU',
#  '',
#  'Kingdom Bank Limited',
#  'EUNICE KAMAU',
#  '',
#  'BENJAMIN MUTIA JUMAA',
#  'Shwari Withdraw',
#  'Shwari Withdraw',
#  '',
#  'FAREEYGRAVY LADIES FASHION1',
#  '',
#  '',
#  'JOHN KAMAU KARIUKI',
#  '',
#  'CLEANSHELF SUPERMARKETS',
#  'Shwari Withdraw',
#  '',
#  'Nakels Co. Ltd',
#  '',
#  'SUSAN KINYANJUI',
#  'JOHN KAMAU WAMBUI',
#  '',
#  '',
#  '',
#  'M',
#  'B2C LOOP VIA',
#  '',
#  '',
#  'Pesa to 254703124627',
#  'BY PASSINN1',
#  '',
#  'Magesh Inv pharmaclan',
#  'ERICK MUSEVE',
#  'ANN WAMBUI KINYANJUI',
#  '',
#  'JAPHLET MWANGI',
#  '',
#  '',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'JOHN MUTINDA',
#  '',
#  '',
#  'Nakels Co. Ltd',
#  '',
#  'Gio Complex Magunga',
#  'GEORGE NJUGUNA NGURU',
#  '',
#  '',
#  '',
#  'Basil Comm Wangige',
#  'BENSON MUTUA',
#  '',
#  'serah mwende mutuku',
#  '',
#  'GEORGE NJUGUNA NGURU',
#  '',
#  'Gio Complex Magunga',
#  'B2C LOOP VIA',
#  '',
#  '',
#  'Pesa to 254719679231',
#  '',
#  '',
#  '',
#  'LINET WANJA NGUGI',
#  '',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'jonh kamotho kuria',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Lurai Ents Ltdvanga',
#  '',
#  'Gio Complex Magunga',
#  'Equity Bulk Account',
#  'JOHN KAMAU WAMBUI',
#  '',
#  'GILBERT BARASA',
#  '',
#  '',
#  'Nakels Co. Ltd',
#  'B2C LOOP VIA',
#  '',
#  'Lurai Ents Ltdvanga',
#  'GEORGE NJUGUNA NGURU',
#  '',
#  ...]

# %%
text = "haha i am big"

# %%
word_cloud
